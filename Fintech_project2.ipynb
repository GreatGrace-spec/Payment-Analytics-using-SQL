# %%
import subprocess
subprocess.run(['pip', 'install', 'mysql-connector-python', 'sqlalchemy', 'pandas', 'openpyxl'])
# Out:
# CompletedProcess(args=['pip', 'install', 'mysql-connector-python', 'sqlalchemy', 'pandas', 'openpyxl'], returncode=0)

# %%
import pandas as pd
from sqlalchemy import create_engine

file_path= r"C:\Users\User\Documents\fintech.xlsx"

transactions = pd.read_excel(r"C:\Users\User\Documents\fintech.xlsx",sheet_name = 'transactions')
merchant = pd.read_excel(r"C:\Users\User\Documents\fintech.xlsx", sheet_name = 'merchants')
fx = pd.read_excel(r"C:\Users\User\Documents\fintech.xlsx", sheet_name = 'fx_rates')
compliance = pd.read_excel(r"C:\Users\User\Documents\fintech.xlsx", sheet_name = 'Compliance_flags')

print("Transactions:", transactions.shape)
print("Merchants:", merchant.shape)
print("FX:", fx.shape)
print("Compliance:", compliance.shape)
# Out:
# Transactions: (40, 8)
# Merchants: (20, 7)
# FX: (16, 5)
# Compliance: (6, 6)

# %%
print("Transaction")
print(transactions.head())
print("Merchant")
print(merchant.head())
print("FX")
print(fx.head())
print("Compliance")
print(compliance.head())
# Out:
# Transaction
#   transaction_id merchant_id   amount currency transaction_type   status  \
# 0        TXN_001   MERCH_001   250000      NGN         transfer  success
# 1        TXN_002   MERCH_001  1850000      NGN         transfer  success
# 2        TXN_003   MERCH_002     5500      GHS          payment  success
# 3        TXN_004   MERCH_003    45000      KES         cash_out   failed
# 4        TXN_005   MERCH_004   125000      NGN          payment  success
#
#    is_fraud          created_at
# 0         0 2024-01-05 09:15:00
# 1         1 2024-01-06 02:30:00
# 2         0 2024-01-07 11:20:00
# 3         0 2024-01-08 14:45:00
# 4         0 2024-01-09 16:00:00
# Merchant
#   merchant_id        merchant_name    business_type       country currency  \
# 0   MERCH_001       Dangote Retail           Retail       Nigeria      NGN
# 1   MERCH_002    Accra Fashion Hub          Fashion         Ghana      GHS
# 2   MERCH_003   Nairobi Tech Store      Electronics         Kenya      KES
# ...

# %%
engine=create_engine('mysql+mysqlconnector://root:NewPassword123!@localhost/fintech_db',echo = False)

transactions.to_sql('transactions', engine, if_exists = 'replace', index = False)
print('transactions loaded')
merchant.to_sql('merchant', engine, if_exists = 'replace', index = False)
print('merchants loaded')
fx.to_sql('fx_rates', engine, if_exists = 'replace', index = False)
print('fx loaded')
compliance.to_sql('compliance_flags', engine, if_exists = 'replace', index = False)
print('Compliance loaded')

print("\nAll tables successfully loaded")
# Out:
# transactions loaded
# merchants loaded
# fx loaded
# Compliance loaded
#
# All tables successfully loaded
